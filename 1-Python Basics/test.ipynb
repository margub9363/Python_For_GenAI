# %%
print (2)
# Out:
# 2

# %%
print('Hello World')
# Out:
# Hello World

# %%
subject = 'python'
def classroom():
    global subject
    subject = 'java'
    print(subject)
def display():
    print(subject)

if __name__ == '__main__':
    classroom()
    # display()
    # print(subject)
# Out:
# java
