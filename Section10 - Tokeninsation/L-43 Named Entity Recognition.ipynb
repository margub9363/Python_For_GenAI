# %%
sentence = "The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk
words=nltk.word_tokenize(sentence)

# %%
nltk.pos_tag(words)
# Out:
# [('The', 'DT'),
#  ('Eiffel', 'NNP'),
#  ('Tower', 'NNP'),
#  ('was', 'VBD'),
#  ('built', 'VBN'),
#  ('from', 'IN'),
#  ('1887', 'CD'),
#  ('to', 'TO'),
#  ('1889', 'CD'),
#  ('by', 'IN'),
#  ('French', 'JJ'),
#  ('engineer', 'NN'),
#  ('Gustave', 'NNP'),
#  ('Eiffel', 'NNP'),
#  (',', ','),
#  ('whose', 'WP$'),
#  ('company', 'NN'),
#  ('specialized', 'VBD'),
#  ('in', 'IN'),
#  ('building', 'NN'),
#  ('metal', 'NN'),
#  ('frameworks', 'NNS'),
#  ('and', 'CC'),
#  ('structures', 'NNS'),
#  ('.', '.')]

# %%
tag_elements = nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to d:\IntellijPracti
# [nltk_data]     ceProjects\Python_For_GenAI\venv\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to d:\IntellijPracticeProjects\P
# [nltk_data]     ython_For_GenAI\venv\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to d:\IntellijPracti
# [nltk_data]     ceProjects\Python_For_GenAI\venv\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to d:\IntellijPracticeProjects\P
# [nltk_data]     ython_For_GenAI\venv\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to d:\IntellijPracticeProjects\P
# [nltk_data]     ython_For_GenAI\venv\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to d:\Intel
# [nltk_data]     lijPracticeProjects\Python_For_GenAI\venv\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('maxent_ne_chunker', download_dir=r"d:\IntellijPracticeProjects\Python_For_GenAI\venv\nltk_data")
nltk.download('words', download_dir=r"d:\IntellijPracticeProjects\Python_For_GenAI\venv\nltk_data")
nltk.download('averaged_perceptron_tagger', download_dir=r"d:\IntellijPracticeProjects\Python_For_GenAI\venv\nltk_data")
nltk.download('punkt', download_dir=r"d:\IntellijPracticeProjects\Python_For_GenAI\venv\nltk_data")
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to d:\IntellijPracti
# [nltk_data]     ceProjects\Python_For_GenAI\venv\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to d:\IntellijPracticeProjects\P
# [nltk_data]     ython_For_GenAI\venv\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to d:\Intel
# [nltk_data]     lijPracticeProjects\Python_For_GenAI\venv\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to d:\IntellijPracticeProjects\P
# [nltk_data]     ython_For_GenAI\venv\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to d:\IntellijPracti
# [nltk_data]     ceProjects\Python_For_GenAI\venv\nltk_data...
# ...

# %%
# !pip install numpy

# %%
# nltk.ne_chunk(tag_elements).draw() << this is not supported in VS code
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 nltk.ne_chunk(tag_elements).draw()
#
# File d:\IntellijPracticeProjects\Python_For_GenAI\venv\Lib\site-packages\nltk\tree\tree.py:761, in Tree.draw(self)
#     756 """
#     757 Open a new window containing a graphical diagram of this tree.
#     758 """
#     759 from nltk.draw.tree import draw_trees
# --> 761 draw_trees(self)
#
# File d:\IntellijPracticeProjects\Python_For_GenAI\venv\Lib\site-packages\nltk\draw\tree.py:1008, in draw_trees(*trees)
#    1001 def draw_trees(*trees):
#    1002     """
#    1003     Open a new window containing a graphical diagram of the given
#    1004     trees.
#    1005
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#
# ...

# %%
tree = nltk.ne_chunk(tag_elements)
tree.pprint()
# Out:
# (S
#   The/DT
#   (ORGANIZATION Eiffel/NNP Tower/NNP)
#   was/VBD
#   built/VBN
#   from/IN
#   1887/CD
#   to/TO
#   1889/CD
#   by/IN
#   (GPE French/JJ)
#   engineer/NN
#   (PERSON Gustave/NNP Eiffel/NNP)
#   ,/,
#   whose/WP$
#   company/NN
#   specialized/VBD
#   in/IN
#   building/NN
#   metal/NN
#   frameworks/NNS
#   and/CC
#   structures/NNS
#   ./.)
