# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
messages = pd.read_csv(
    'spam.csv',
    sep='\t',
    names=["label", "message"],
    encoding='latin-1'
)

# %%
messages
# Out:
#                                                   label  message
# 0                                              v1,v2,,,      NaN
# 1     ham,"Go until jurong point, crazy.. Available ...      NaN
# 2                  ham,Ok lar... Joking wif u oni...,,,      NaN
# 3     spam,Free entry in 2 a wkly comp to win FA Cup...      NaN
# 4     ham,U dun say so early hor... U c already then...      NaN
# ...                                                 ...      ...
# 5570  spam,"This is the 2nd time we have tried 2 con...      NaN
# 5571       ham,Will Ì_ b going to esplanade fr home?,,,      NaN
# 5572  ham,"Pity, * was in mood for that. So...any ot...      NaN
# 5573  ham,The guy did some bitching but I acted like...      NaN
# 5574                  ham,Rofl. Its true to its name,,,      NaN
#
# [5575 rows x 2 columns]

# %%
## Data Cleaning And Preprocessing
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to d:\IntellijPracticeProjec
# [nltk_data]     ts\Python_For_GenAI\venv\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
