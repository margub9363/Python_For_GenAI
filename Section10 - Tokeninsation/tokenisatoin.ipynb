# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (3.9.2)
# Requirement already satisfied: click in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\intellijpracticeprojects\python_for_genai\venv\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus="""Hello Welcome, to Krish Naik's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

print(corpus)
# Out:
# Hello Welcome, to Krish Naik's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab') 


from nltk.tokenize import sent_tokenize
documents = sent_tokenize(corpus)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\margu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\margu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to Krish Naik's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
# Tokenization
# Paragraph --> words
# sentence --> words

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
